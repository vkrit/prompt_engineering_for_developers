# %% [markdown]
# ## Library Setup

# %%
# !pip install openai
# !pip install python-dotenv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import openai
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

#openai.api_key  = os.getenv('OPENAI_API_KEY')
openai.api_key  = ""

# %% [markdown]
# ## Helper Function

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

def get_completion_from_messages(message, temperature, model="gpt-3.5-turbo"):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )
    return response.choices[0].message["content"]

# %% [markdown]
# ## Role for Chatbot

# %%
messages = [{'role':'system', 'content':'you are an assistant that speaks like Shakespeare'},
{'role':'user', 'content':'tell me a joke'},
{'role':'assistant', 'content':'why chicken crosss the road'},
{'role':'user', 'content':"I don't know"}]

# %%
response = get_completion_from_messages(messages, temperature=1)

# %%
print(response)
# Out:
# To get to the other side, my lord!

# %%
messages = [{'role':'system', 'content': 'you are a friendly chatbot'},
            {'role':'user', 'content': 'my name is veerasak'}]

# %%
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Hello Veerasak! It's nice to meet you. How can I assist you today?

# %%
messages = [{'role':'system', 'content': 'you are a friendly chatbot'},
            {'role':'user', 'content': 'Can you remind me what is my name?'}]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# I apologize but as a chatbot, I don't have access to your personal information, so I don't know your name. Can you please tell me your name?

# %%
messages = [{'role':'system', 'content': 'you are a friendly chatbot'},
            {'role':'user', 'content': 'my name is veerasak'},
            {'role':'system', 'content': 'you are a friendly chatbot'},
            {'role':'user', 'content': 'Can you remind me what is my name?'}]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Your name is Veerasak!

# %%
def collect_messages (_):
  prompt = inp.value_input
  inp.value =''
  context.append({'role': 'user', 'content' :f" {prompt}" })
  response = get_completion_from_messages(context)
  context.append({'role': 'assistant', 'content' :f" {response
  panels.append(pn.Row('User:', pn.pane. Markdown (prompt, width=600))
  panels.append (pn.Row('Assistant:', pn.pane.Markdown (response, widt.
  return pn.Column (*panels)
